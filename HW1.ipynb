# %%
n = int(input())
print (2*n)
# Out:
# 4

# %%
a = float(input())
b = float(input())
S_hcn = a*b
S_htron = 3.14 * (a/2)**2
S_conlai = S_hcn - S_htron
print (round(S_conlai, 2))
# Out:
# 30.38

# %%
c = input()
if c.isupper():
    print(c.lower())
elif c.islower():
    print(c.upper())
# Out:
# e

# %%
c = input()
if c.isalpha():
    print(" {c} la ki tu alphabet")
else:
    print("{c} khong la ki tu alphabet")
# Out:
#  {c} la ki tu alphabet

# %%
c = input()
if c == 'A':
    print("TH dac biet: khong co chu cai thuong trc 'a'")
else:
    c_thuong = c.lower()
    truoc = chr(ord(c_thuong) -1 )
    print ("chu thuong lien trc la", truoc )
# Out:
# chu thuong lien trc la a

# %%
import math
a = float(input())
b = float(input())
c = float(input())
if a+b>c and a+c>b and b+c>a:
    p = (a+b+c)/2
    S = math.sqrt(p*(p-a)*(p-b)*(p-c))
    print(format(S, ".1f"))
else:
    print("Khong phai 3 canh cua tam giac")
# Out:
# 6.0

# %%
chuoi = input()
if len(chuoi)>=20:
    print("ky tu thu 5 la",chuoi[4])
    print("ku tu thu 9 la",chuoi[9])
else:
    print("chuoi khong du do dai")
# Out:
# ky tu thu 5 la 5
# ku tu thu 9 la 9

# %%
ten_chu_ho = input("Ten chu ho:")
chi_so_truoc = int(input("Chi so truoc:"))
chi_so_sau = int(input("Chi so sau:"))
so_dien = chi_so_sau - chi_so_truoc
tien_dien = 0
if so_dien <= 50:
    tien_dien = (so_dien * 1984)
elif so_dien <= 100:
    tien_dien = 50 * 1984 +  (so_dien-50)*2050
elif so_dien <= 200:
    tien_dien = 50 *1984 + 50*2050 +(so_dien - 100)*2380
elif so_dien <= 300 :
    tien_dien = 50*1984 + 50*2050 + 100*2380+(so_dien - 200)*2998
elif so_dien >= 400:
    tien_dien = 50*1984 + 50*2050 + 100*2380+100*2998 + (so_dien -300)*3350
elif so_dien >= 401:
    tien_dien = 50*1984 +50*2050 + 100*2380+100*2998+100*3350 +(so_dien-400)*3460
vat = tien_dien *0.08
tong_tien = int(tien_dien + vat)
print ("Ho va ten: ", ten_chu_ho)
print("Tien phai tra la :",tong_tien)
# Out:
# Ho va ten:  Nguyen Xuan Long
# Tien phai tra la : 426038

# %%
c = int(input())
if c%2 ==0:
    print ("{c} la so chan")
else :
    print ("{c} la so le")
# Out:
# {c} la so chan

# %%
c = int(input())
if c%10 ==5:
    print ("True")
else:
    print ("False")
# Out:
# True

# %%
c = int(input())
if c%5==0 and c%3 ==0:
    print ("True")
else:
    print("False")
# Out:
# True

# %%
nam_sinh = int(input())
tuoi = 2025 - nam_sinh
if tuoi < 18 :
    print ("Chua du tuoi di bau cu")
else:
    print ("Da du tuoi")
# Out:
# Da du tuoi

# %%
a = int(input())
b = int(input())
if a > b :
    print ("So a lon hon so b")
elif a < b :
    print ("So b lon hon so a")
else:
    print (" Hai so bang nhau")
# Out:
# So a lon hon so b

# %%
c = input()
if c.isalpha():
    print("chu")
elif c.isdigit():
    print("so")
# Out:
# chu

# %%
c = int(input())
if c>= 8:
    print("Gioi")
elif c>= 6.5 and c <8:
    print("Kha")
elif c >= 5 and c<6.5:
    print("Trung binh")
else:
    print("Yeu")
# Out:
# Yeu

# %%
nam = int(input())
if nam % 400==0:
    print("Nam nhuan")
else:
    print("Nam binh thuong")
# Out:
# Nam nhuan

# %%
c = int(input())
match c:
    case 0:
        print("Khong")
    case 1:
        print("Mot")
    case 2:
        print("Hai")
    case 3:
        print("Ba")
    case 4:
        print("Bon")
    case 5:
        print("Nam")
    case 6:
        print("Sau")
    case 7:
        print("Bay")
    case 8:
        print("Tam")
    case 9:
        print("Chin")
# Out:
# Nam

# %%
diem_thi = int(input())
if diem_thi >= 4 :
    print ("Qua mon")
else :
    print("Hoc lai")
# Out:
# Qua mon

# %%
nam_sinh = int(input())
tuoi = 2025 - nam_sinh
if tuoi < 18 :
    print("Chua du tuoi")
else:
    print("Da du tuoi")
# Out:
# Da du tuoi
