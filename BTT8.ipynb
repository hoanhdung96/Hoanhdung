# %%
#W7A1
def linear_search(arr , value):
    for i in range(len(arr)):
        if arr[i] == value :
            return i
    return -1
arr = list(map(int, input().split()))
value = int(input())
print(linear_search(arr, value))
# Out:
# -1

# %%
#W7A1
def binary_search(arr , value):
    left , right = 0 , len(arr) - 1
    while left <= right :
        mid = (left + right) // 2
        if arr[mid] == value:
            return mid
        elif arr[mid] < value:
            left = mid + 1
        else :
            right = mid - 1
    return -1
arr = list(map(int, input().split()))
value = int(input())
print(binary_search(arr, value))
# Out:
# 4

# %%
#W7A2
def count_occurrences(nums, x):
    cnt = 0
    for i in nums:
        if i == x :
            cnt += 1
    return cnt
nums = list(map(int, input().split()))
x = int(input())
print(count_occurrences(nums, x))
# Out:
# 0

# %%
#W7A3
def bubble_sort(nums):
    n = len(nums)
    for i in range(n):
        swapped = False
        for j in range(0 , n - i - 1 ):
            if nums[j] > nums[j+1]:
                nums[j], nums[j+1] = nums[j+1] , nums[j]
                swapped = True
        if not swapped:
            break
    return nums
nums = list(map(int, input().split()))
print(bubble_sort(nums))
# Out:
# [7, 25, 39, 40]

# %%
#W7A3
def selection_sort(nums):
    n = len(nums)
    for i in range(n):
        min_idx = i
        for j in range( i + 1 , n ):
            if nums[j] < nums[min_idx]:
                min_idx = j
        nums[i] , nums[min_idx] = nums[min_idx], nums[i]
    return nums
nums = list(map(int, input().split()))
print(selection_sort(nums))
# Out:
# [7, 25, 39, 40]

# %%
#7A4
def most_appearances(arr):
    d = {}
    for x in arr:
        if x not in d:
            d[x] = 1
        else:
            d[x] += 1
    max_d = max(d.values())
    for x in d:
        if d[x] == max_d:
            return (f"{x} xuat hien nhieu lan nhat, som nhat, {max_d} lan")

arr = list(map(int, input().split()))
print(most_appearances(arr))
# Out:
# 1 xuat hien nhieu lan nhat, som nhat,2 lan

# %%
#W7A5
nums = list(map(int, input().split()))
X = int(input())
n = len(nums)
cnt = 0
for i in range(n):
    for j in range(i+1, n):
        if nums[i] + nums[j] == X:
            cnt += 1
print(cnt)
# Out:
# 6

# %%
#W7A6
nested = [[1,2],[3,4],[5,6]]
flat = sum(nested,[])
print(flat)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#W7A7
nums = list(map(int, input().split()))
n = len(nums)
result = [1] * n
for i in range(n):
    for j in range(i):
        if nums[j] < nums[i]:
            result[i] = max(result[i], result[j] + 1)
print(max(result))
# Out:
# 5

# %%
#W7A9
nums = list(map(int, input().split()))
result = []
n = len(nums)
for i in range(n):
    cnt = 0
    for j in range(i + 1 , n):
        if nums[i] > nums[j]:
            cnt += 1
    result.append(cnt)
print(result)
# Out:
# [2, 1, 1, 0]

# %%
#W7A11
text = input().strip()
key = input().strip()
count = text.count(key)
print(count)
# Out:
# 5

# %%
#W7A14
k = int(input("Nhap do dai cua day so"))
nums = list(map(int, input("Nhap day").split()))
n = len(nums)
print(k)
print(nums)
for i in range(n):
    if nums[i] == 7 :
        print("Vi tri chua so 7 la:",i)
# Out:
# 5
# [7, 7, 7, 7, 7]
# Vi tri chua so 7 la: 0
# Vi tri chua so 7 la: 1
# Vi tri chua so 7 la: 2
# Vi tri chua so 7 la: 3
# Vi tri chua so 7 la: 4

# %%
#W7A15
n = int(input("Nhap so luong khach moi"))
guest = [input().strip() for a in range(n)]
for i in range(n):
    if guest[i] == "Nemo":
        if i > 0 and i < n - 1 :
            name1 = guest[i-1]
            name2 = guest[i+1]
            print(f"{name1} and {name2}")
        elif i == 0 :
            print(f"{guest[n-1]} and {guest[i+1]}")
        elif i == n - 1 :
            print(f"{guest[n-2]} and {guest[0]}")
        else:
            print("Nemo k co ai ngoi canh")
# Out:
# Gildur and Elsu
